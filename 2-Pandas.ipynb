# %% [markdown]
# # Pandas in Python for Data Science

# %% [markdown]
# **Pandas**
#
# pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real-world data analysis in Python.
#
# **Library Highlights**
#
# 1. A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# 2. Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# 3. Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# 4. Flexible reshaping and pivoting of data sets;
#
# 5. Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# 6. Columns can be inserted and deleted from data structures for size mutability;
#
# 7. Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# 8. High performance merging and joining of data sets;
#
# 9. Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
#
# 10. Time series-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
#
# 11. Highly optimized for performance, with critical code paths written in Cython or C.
#
# 12. Python with pandas is in use in a wide variety of academic and commercial domains, including Finance, Neuroscience, Economics, Statistics, Advertising, Web Analytics, and more.

# %% [markdown]
# ## Section 5.1: Basic Functions of Pandas in Python

# %% [markdown]
# > Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
# Object Creation
s = pd.Series([1,3, np.nan, 5,7,8,9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    5.0
# 4    7.0
# 5    8.0
# 6    9.0
# dtype: float64

# %%
dates = pd.date_range("20220111" , periods= 7)
dates
# Out:
# DatetimeIndex(['2022-01-11', '2022-01-12', '2022-01-13', '2022-01-14',
#                '2022-01-15', '2022-01-16', '2022-01-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.DataFrame(np.random.randn(7,4), index = dates, columns= list("ABCD"))
dates
# Out:
#                    A         B         C         D
# 2022-01-11 -0.409490  0.691129  0.344665 -0.883404
# 2022-01-12 -2.712033 -1.927415 -0.849799 -0.861770
# 2022-01-13 -0.173250  0.697179 -0.191201 -0.522708
# 2022-01-14 -0.276423 -0.952830  1.240734  0.413146
# 2022-01-15  1.058941  0.186696  0.246766  0.297042
# 2022-01-16  1.529537 -1.935374 -1.153904 -0.656822
# 2022-01-17  0.051854  0.621652 -0.038796  0.449270

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(phool)
# Out:
# pandas.core.frame.DataFrame

# %%
phool.to_csv("iris.csv")

# %%
phool.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
phool.mean()
# Out:
# C:\Users\ammar\AppData\Local\Temp/ipykernel_8796/2868387341.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   phool.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
phool.median()
# Out:
# C:\Users\ammar\AppData\Local\Temp/ipykernel_8796/4022828141.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   phool.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
# Price of Pakora, Samosa in Video No. 28
price = pd.Series([30,30,35,45,10,61,70,90,115])
price
# Out:
# 0     30
# 1     30
# 2     35
# 3     45
# 4     10
# 5     61
# 6     70
# 7     90
# 8    115
# dtype: int64

# %%
price.mean()
# Out:
# 54.0

# %%
price.median()
# Out:
# 45.0

# %%
price.mode()
# Out:
# 0    30
# dtype: int64

# %%
price.std()
# Out:
# 33.26409475695979

# %%
price.var()
# Out:
# 1106.5

# %%
price.min()
# Out:
# 10

# %%
price.max()
# Out:
# 115

# %% [markdown]
# ## Section 5.2: Pandas Library Functions on FAO Data Set

# %%
Fert_PK = pd.read_csv("Pak - Fertilizers consumption in nutrients.csv")
Fert_PK
# Out:
#      Year      Area  Item Code                             Item  Year Code  \
# 0    1961  Pakistan       3102      Nutrient nitrogen N (total)       1961
# 1    1961  Pakistan       3103  Nutrient phosphate P2O5 (total)       1961
# 2    1962  Pakistan       3103  Nutrient phosphate P2O5 (total)       1962
# 3    1962  Pakistan       3102      Nutrient nitrogen N (total)       1962
# 4    1963  Pakistan       3102      Nutrient nitrogen N (total)       1963
# ..    ...       ...        ...                              ...        ...
# 167  2018  Pakistan       3102      Nutrient nitrogen N (total)       2018
# 168  2018  Pakistan       3104      Nutrient potash K2O (total)       2018
# 169  2019  Pakistan       3104      Nutrient potash K2O (total)       2019
# 170  2019  Pakistan       3102      Nutrient nitrogen N (total)       2019
# 171  2019  Pakistan       3103  Nutrient phosphate P2O5 (total)       2019
#
#        Unit    Value
# 0    tonnes    41659
# 1    tonnes      500
# 2    tonnes      210
# 3    tonnes    41160
# 4    tonnes    67620
# ..      ...      ...
# 167  tonnes  3446922
# 168  tonnes    54173
# 169  tonnes    47260
# 170  tonnes  3505356
# 171  tonnes  1099707
#
# [172 rows x 7 columns]

# %% [markdown]
# ### 5.2.1: Set Index

# %%
Fert_PK.set_index('Year')
# Out:
#           Area  Item Code                             Item  Year Code    Unit  \
# Year
# 1961  Pakistan       3102      Nutrient nitrogen N (total)       1961  tonnes
# 1961  Pakistan       3103  Nutrient phosphate P2O5 (total)       1961  tonnes
# 1962  Pakistan       3103  Nutrient phosphate P2O5 (total)       1962  tonnes
# 1962  Pakistan       3102      Nutrient nitrogen N (total)       1962  tonnes
# 1963  Pakistan       3102      Nutrient nitrogen N (total)       1963  tonnes
# ...        ...        ...                              ...        ...     ...
# 2018  Pakistan       3102      Nutrient nitrogen N (total)       2018  tonnes
# 2018  Pakistan       3104      Nutrient potash K2O (total)       2018  tonnes
# 2019  Pakistan       3104      Nutrient potash K2O (total)       2019  tonnes
# 2019  Pakistan       3102      Nutrient nitrogen N (total)       2019  tonnes
# 2019  Pakistan       3103  Nutrient phosphate P2O5 (total)       2019  tonnes
#
#         Value
# Year
# 1961    41659
# 1961      500
# 1962      210
# 1962    41160
# 1963    67620
# ...       ...
# 2018  3446922
# 2018    54173
# 2019    47260
# 2019  3505356
# 2019  1099707
#
# [172 rows x 6 columns]

# %% [markdown]
# ### 5.2.2: Data Types

# %%
Fert_PK.dtypes
# Out:
# Year          int64
# Area         object
# Item Code     int64
# Item         object
# Year Code     int64
# Unit         object
# Value         int64
# dtype: object

# %% [markdown]
# ### 5.2.3: Head & Tail View of Data Frame

# %%
Fert_PK.head()
# Out:
#    Year      Area  Item Code                             Item  Year Code  \
# 0  1961  Pakistan       3102      Nutrient nitrogen N (total)       1961
# 1  1961  Pakistan       3103  Nutrient phosphate P2O5 (total)       1961
# 2  1962  Pakistan       3103  Nutrient phosphate P2O5 (total)       1962
# 3  1962  Pakistan       3102      Nutrient nitrogen N (total)       1962
# 4  1963  Pakistan       3102      Nutrient nitrogen N (total)       1963
#
#      Unit  Value
# 0  tonnes  41659
# 1  tonnes    500
# 2  tonnes    210
# 3  tonnes  41160
# 4  tonnes  67620

# %%
Fert_PK.tail()
# Out:
#      Year      Area  Item Code                             Item  Year Code  \
# 167  2018  Pakistan       3102      Nutrient nitrogen N (total)       2018
# 168  2018  Pakistan       3104      Nutrient potash K2O (total)       2018
# 169  2019  Pakistan       3104      Nutrient potash K2O (total)       2019
# 170  2019  Pakistan       3102      Nutrient nitrogen N (total)       2019
# 171  2019  Pakistan       3103  Nutrient phosphate P2O5 (total)       2019
#
#        Unit    Value
# 167  tonnes  3446922
# 168  tonnes    54173
# 169  tonnes    47260
# 170  tonnes  3505356
# 171  tonnes  1099707

# %% [markdown]
# ### 5.2.4: Convert Data Frame to NumPy Array

# %%
Fert_PK.to_numpy()
# Out:
# array([[1961, 'Pakistan', 3102, ..., 1961, 'tonnes', 41659],
#        [1961, 'Pakistan', 3103, ..., 1961, 'tonnes', 500],
#        [1962, 'Pakistan', 3103, ..., 1962, 'tonnes', 210],
#        ...,
#        [2019, 'Pakistan', 3104, ..., 2019, 'tonnes', 47260],
#        [2019, 'Pakistan', 3102, ..., 2019, 'tonnes', 3505356],
#        [2019, 'Pakistan', 3103, ..., 2019, 'tonnes', 1099707]],
#       dtype=object)

# %% [markdown]
# ### 5.2.5 Summary of Data frame

# %%
Fert_PK.describe()
# Out:
#               Year    Item Code    Year Code         Value
# count   172.000000   172.000000   172.000000  1.720000e+02
# mean   1990.784884  3102.970930  1990.784884  7.064396e+05
# std      16.678775     0.812385    16.678775  9.709749e+05
# min    1961.000000  3102.000000  1961.000000  1.440000e+02
# 25%    1976.750000  3102.000000  1976.750000  2.615950e+04
# 50%    1991.000000  3103.000000  1991.000000  2.689255e+05
# 75%    2005.000000  3104.000000  2005.000000  9.193622e+05
# max    2019.000000  3104.000000  2019.000000  3.505356e+06

# %%
Fert_PK.index
# Out:
# RangeIndex(start=0, stop=172, step=1)

# %%
Fert_PK.columns
# Out:
# Index(['Year', 'Area', 'Item Code', 'Item', 'Year Code', 'Unit', 'Value'], dtype='object')

# %% [markdown]
# ### 5.2.6 Sorting Data Frame

# %%
Fert_PK.sort_index(axis=1, ascending=True)
# Out:
#          Area                             Item  Item Code    Unit    Value  \
# 0    Pakistan      Nutrient nitrogen N (total)       3102  tonnes    41659
# 1    Pakistan  Nutrient phosphate P2O5 (total)       3103  tonnes      500
# 2    Pakistan  Nutrient phosphate P2O5 (total)       3103  tonnes      210
# 3    Pakistan      Nutrient nitrogen N (total)       3102  tonnes    41160
# 4    Pakistan      Nutrient nitrogen N (total)       3102  tonnes    67620
# ..        ...                              ...        ...     ...      ...
# 167  Pakistan      Nutrient nitrogen N (total)       3102  tonnes  3446922
# 168  Pakistan      Nutrient potash K2O (total)       3104  tonnes    54173
# 169  Pakistan      Nutrient potash K2O (total)       3104  tonnes    47260
# 170  Pakistan      Nutrient nitrogen N (total)       3102  tonnes  3505356
# 171  Pakistan  Nutrient phosphate P2O5 (total)       3103  tonnes  1099707
#
#      Year  Year Code
# 0    1961       1961
# 1    1961       1961
# 2    1962       1962
# 3    1962       1962
# 4    1963       1963
# ..    ...        ...
# 167  2018       2018
# 168  2018       2018
# 169  2019       2019
# 170  2019       2019
# 171  2019       2019
#
# [172 rows x 7 columns]

# %%
Fert_PK.sort_values(by="Value", ascending=False)
# Out:
#      Year      Area  Item Code                             Item  Year Code  \
# 170  2019  Pakistan       3102      Nutrient nitrogen N (total)       2019
# 140  2009  Pakistan       3102      Nutrient nitrogen N (total)       2009
# 167  2018  Pakistan       3102      Nutrient nitrogen N (total)       2018
# 164  2017  Pakistan       3102      Nutrient nitrogen N (total)       2017
# 143  2010  Pakistan       3102      Nutrient nitrogen N (total)       2010
# ..    ...       ...        ...                              ...        ...
# 5    1963  Pakistan       3103  Nutrient phosphate P2O5 (total)       1963
# 1    1961  Pakistan       3103  Nutrient phosphate P2O5 (total)       1961
# 13   1967  Pakistan       3104      Nutrient potash K2O (total)       1967
# 2    1962  Pakistan       3103  Nutrient phosphate P2O5 (total)       1962
# 12   1966  Pakistan       3104      Nutrient potash K2O (total)       1966
#
#        Unit    Value
# 170  tonnes  3505356
# 140  tonnes  3451900
# 167  tonnes  3446922
# 164  tonnes  3446922
# 143  tonnes  3270531
# ..      ...      ...
# 5    tonnes      630
# 1    tonnes      500
# 13   tonnes      212
# 2    tonnes      210
# 12   tonnes      144
#
# [172 rows x 7 columns]

# %%
Fert_PK[0:5]
# Out:
#    Year      Area  Item Code                             Item  Year Code  \
# 0  1961  Pakistan       3102      Nutrient nitrogen N (total)       1961
# 1  1961  Pakistan       3103  Nutrient phosphate P2O5 (total)       1961
# 2  1962  Pakistan       3103  Nutrient phosphate P2O5 (total)       1962
# 3  1962  Pakistan       3102      Nutrient nitrogen N (total)       1962
# 4  1963  Pakistan       3102      Nutrient nitrogen N (total)       1963
#
#      Unit  Value
# 0  tonnes  41659
# 1  tonnes    500
# 2  tonnes    210
# 3  tonnes  41160
# 4  tonnes  67620

# %% [markdown]
# ### 5.2.7 Selecting Data using Label Based (loc)

# %%
Fert_PK.loc[10]
# Out:
# Year                                    1966
# Area                                Pakistan
# Item Code                               3103
# Item         Nutrient phosphate P2O5 (total)
# Year Code                               1966
# Unit                                  tonnes
# Value                                   3911
# Name: 10, dtype: object

# %%
Fert_PK.loc[:, ["Year", "Item", "Value"]]
# Out:
#      Year                             Item    Value
# 0    1961      Nutrient nitrogen N (total)    41659
# 1    1961  Nutrient phosphate P2O5 (total)      500
# 2    1962  Nutrient phosphate P2O5 (total)      210
# 3    1962      Nutrient nitrogen N (total)    41160
# 4    1963      Nutrient nitrogen N (total)    67620
# ..    ...                              ...      ...
# 167  2018      Nutrient nitrogen N (total)  3446922
# 168  2018      Nutrient potash K2O (total)    54173
# 169  2019      Nutrient potash K2O (total)    47260
# 170  2019      Nutrient nitrogen N (total)  3505356
# 171  2019  Nutrient phosphate P2O5 (total)  1099707
#
# [172 rows x 3 columns]

# %%
Fert_PK.loc[[0], "Value"]
# Out:
# 0    41659
# Name: Value, dtype: int64

# %% [markdown]
# ### 5.2.8: Selecting Data using Label Based (loc function)

# %%
Fert_PK.iloc[0]
# Out:
# Year                                1961
# Area                            Pakistan
# Item Code                           3102
# Item         Nutrient nitrogen N (total)
# Year Code                           1961
# Unit                              tonnes
# Value                              41659
# Name: 0, dtype: object

# %%
Fert_PK[Fert_PK["Year"] > 2000]
# Out:
#      Year      Area  Item Code                             Item  Year Code  \
# 115  2001  Pakistan       3104      Nutrient potash K2O (total)       2001
# 116  2001  Pakistan       3102      Nutrient nitrogen N (total)       2001
# 117  2001  Pakistan       3103  Nutrient phosphate P2O5 (total)       2001
# 118  2002  Pakistan       3103  Nutrient phosphate P2O5 (total)       2002
# 119  2002  Pakistan       3102      Nutrient nitrogen N (total)       2002
# 120  2002  Pakistan       3104      Nutrient potash K2O (total)       2002
# 121  2003  Pakistan       3104      Nutrient potash K2O (total)       2003
# 122  2003  Pakistan       3102      Nutrient nitrogen N (total)       2003
# 123  2003  Pakistan       3103  Nutrient phosphate P2O5 (total)       2003
# 124  2004  Pakistan       3103  Nutrient phosphate P2O5 (total)       2004
# 125  2004  Pakistan       3102      Nutrient nitrogen N (total)       2004
# 126  2004  Pakistan       3104      Nutrient potash K2O (total)       2004
# 127  2005  Pakistan       3104      Nutrient potash K2O (total)       2005
# 128  2005  Pakistan       3102      Nutrient nitrogen N (total)       2005
# 129  2005  Pakistan       3103  Nutrient phosphate P2O5 (total)       2005
# 130  2006  Pakistan       3103  Nutrient phosphate P2O5 (total)       2006
# 131  2006  Pakistan       3102      Nutrient nitrogen N (total)       2006
# 132  2006  Pakistan       3104      Nutrient potash K2O (total)       2006
# 133  2007  Pakistan       3104      Nutrient potash K2O (total)       2007
# 134  2007  Pakistan       3102      Nutrient nitrogen N (total)       2007
# 135  2007  Pakistan       3103  Nutrient phosphate P2O5 (total)       2007
# 136  2008  Pakistan       3103  Nutrient phosphate P2O5 (total)       2008
# 137  2008  Pakistan       3102      Nutrient nitrogen N (total)       2008
# 138  2008  Pakistan       3104      Nutrient potash K2O (total)       2008
# 139  2009  Pakistan       3104      Nutrient potash K2O (total)       2009
# 140  2009  Pakistan       3102      Nutrient nitrogen N (total)       2009
# 141  2009  Pakistan       3103  Nutrient phosphate P2O5 (total)       2009
# 142  2010  Pakistan       3103  Nutrient phosphate P2O5 (total)       2010
# 143  2010  Pakistan       3102      Nutrient nitrogen N (total)       2010
# 144  2010  Pakistan       3104      Nutrient potash K2O (total)       2010
# 145  2011  Pakistan       3104      Nutrient potash K2O (total)       2011
# 146  2011  Pakistan       3102      Nutrient nitrogen N (total)       2011
# 147  2011  Pakistan       3103  Nutrient phosphate P2O5 (total)       2011
# 148  2012  Pakistan       3103  Nutrient phosphate P2O5 (total)       2012
# 149  2012  Pakistan       3102      Nutrient nitrogen N (total)       2012
# 150  2012  Pakistan       3104      Nutrient potash K2O (total)       2012
# 151  2013  Pakistan       3104      Nutrient potash K2O (total)       2013
# 152  2013  Pakistan       3102      Nutrient nitrogen N (total)       2013
# 153  2013  Pakistan       3103  Nutrient phosphate P2O5 (total)       2013
# 154  2014  Pakistan       3103  Nutrient phosphate P2O5 (total)       2014
# 155  2014  Pakistan       3102      Nutrient nitrogen N (total)       2014
# 156  2014  Pakistan       3104      Nutrient potash K2O (total)       2014
# 157  2015  Pakistan       3104      Nutrient potash K2O (total)       2015
# 158  2015  Pakistan       3102      Nutrient nitrogen N (total)       2015
# 159  2015  Pakistan       3103  Nutrient phosphate P2O5 (total)       2015
# 160  2016  Pakistan       3103  Nutrient phosphate P2O5 (total)       2016
# 161  2016  Pakistan       3102      Nutrient nitrogen N (total)       2016
# 162  2016  Pakistan       3104      Nutrient potash K2O (total)       2016
# 163  2017  Pakistan       3104      Nutrient potash K2O (total)       2017
# 164  2017  Pakistan       3102      Nutrient nitrogen N (total)       2017
# 165  2017  Pakistan       3103  Nutrient phosphate P2O5 (total)       2017
# 166  2018  Pakistan       3103  Nutrient phosphate P2O5 (total)       2018
# 167  2018  Pakistan       3102      Nutrient nitrogen N (total)       2018
# 168  2018  Pakistan       3104      Nutrient potash K2O (total)       2018
# 169  2019  Pakistan       3104      Nutrient potash K2O (total)       2019
# 170  2019  Pakistan       3102      Nutrient nitrogen N (total)       2019
# 171  2019  Pakistan       3103  Nutrient phosphate P2O5 (total)       2019
#
#        Unit    Value
# 115  tonnes    10900
# 116  tonnes  2291610
# 117  tonnes   641940
# 118  tonnes   647360
# 119  tonnes  2384980
# 120  tonnes    20500
# 121  tonnes    23944
# 122  tonnes  2456009
# 123  tonnes   669307
# 124  tonnes   761031
# 125  tonnes  2570230
# 126  tonnes    26449
# 127  tonnes    35301
# 128  tonnes  2818779
# 129  tonnes   871416
# 130  tonnes   906749
# 131  tonnes  2868984
# 132  tonnes    36408
# 133  tonnes    43924
# 134  tonnes  2714053
# 135  tonnes   816044
# 136  tonnes   565675
# 137  tonnes  2928057
# 138  tonnes    16564
# 139  tonnes    15499
# 140  tonnes  3451900
# 141  tonnes   778714
# 142  tonnes   756700
# 143  tonnes  3270531
# 144  tonnes    37545
# 145  tonnes    28013
# 146  tonnes  3187339
# 147  tonnes   653181
# 148  tonnes   678840
# 149  tonnes  2850771
# 150  tonnes    19427
# 151  tonnes    19849
# 152  tonnes  3239557
# 153  tonnes   875452
# 154  tonnes   936148
# 155  tonnes  3139263
# 156  tonnes    29549
# 157  tonnes    25291
# 158  tonnes  3160507
# 159  tonnes   993338
# 160  tonnes  1209145
# 161  tonnes  3241907
# 162  tonnes    28954
# 163  tonnes    54173
# 164  tonnes  3446922
# 165  tonnes  1257773
# 166  tonnes  1257773
# 167  tonnes  3446922
# 168  tonnes    54173
# 169  tonnes    47260
# 170  tonnes  3505356
# 171  tonnes  1099707

# %%
p = (Fert_PK['Value'] / Fert_PK['Value'].sum()) * 100
p
# Out:
# 0      0.034285
# 1      0.000411
# 2      0.000173
# 3      0.033874
# 4      0.055651
#          ...
# 167    2.836795
# 168    0.044584
# 169    0.038895
# 170    2.884886
# 171    0.905052
# Name: Value, Length: 172, dtype: float64

# %%
p.sum()
# Out:
# 100.0

# %% [markdown]
# ### 5.2.9: Groupby in Pandas

# %%
sum_Fert = Fert_PK.groupby(['Year', 'Item'])[["Value"]].sum()
sum_Fert
# Out:
#                                         Value
# Year Item
# 1961 Nutrient nitrogen N (total)        41659
#      Nutrient phosphate P2O5 (total)      500
# 1962 Nutrient nitrogen N (total)        41160
#      Nutrient phosphate P2O5 (total)      210
# 1963 Nutrient nitrogen N (total)        67620
# ...                                       ...
# 2018 Nutrient phosphate P2O5 (total)  1257773
#      Nutrient potash K2O (total)        54173
# 2019 Nutrient nitrogen N (total)      3505356
#      Nutrient phosphate P2O5 (total)  1099707
#      Nutrient potash K2O (total)        47260
#
# [172 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize= (10,8))
sns.lineplot(x="Year" , y = "Value" , hue= "Item",data = Fert_PK)
# Fert_PK.plot.line(x="Year" , y = "" , figsize = (10,12))
plt.show()
