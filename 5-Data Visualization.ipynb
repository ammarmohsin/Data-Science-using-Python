# %% [markdown]
# # Data Visualization

# %% [markdown]
# In today’s world, a lot of data is being generated on a daily basis. And sometimes to analyze this data for certain trends, patterns may become difficult if the data is in its raw format. To overcome this data visualization comes into play. Data visualization provides a good, organized pictorial representation of the data which makes it easier to understand, observe, analyze.
#
# ### Data Visualization
#
# Data visualization is a field in data analysis that deals with visual representation of data. It graphically plots data and is an effective way to communicate inferences from data. Using data visualization, we can get a visual summary of our data. With pictures, maps and graphs, the human mind has an easier time processing and understanding any given data. Data visualization plays a significant role in the representation of both small and large data sets, but it is especially useful when we have large data sets, in which it is impossible to see all of our data, let alone process and understand it manually.
#
# ### Data Visualization in Python
#
# Python offers several plotting libraries, namely Matplotlib, Seaborn and many other such data visualization packages with different features for creating informative, customized, and appealing plots to present data in the most simple and effective way.
#
# **Libraries**
#
# 1. Matplotlib
# 2. Seaborn
# 3. Plotly

# %% [markdown]
# ### How to Choose Right Graph?
#
# ![](abela-chart-chooser.jpg)

# %% [markdown]
# **Steps Involved in Data Visualization:**
# 1. Import Libraries
# 2. Import Data Set
# 3. Plot a Graph (Lineplot, Barplot, Boxplot, Countplot etc.)
# 4. Set a Theme of the plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
boat = sns.load_dataset("titanic")
p = sns.countplot(x = "sex", data = boat, hue = "class")
sns.set_theme(style = "ticks", color_codes = True)
p.set_title("Titanic Dataset")
plt.show()

# %%
import pandas as pd

# import data from file
class_data = pd.read_csv("data_viz.csv")
class_data
# Out:
#              Timestamp  Gender    Age  Location Time of class (pm)  \
# 0    1/3/2022 19:09:29    Male  16-30  Pakistan              10:30
# 1    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 2    1/3/2022 19:09:33    Male  16-30  Pakistan              10:00
# 3    1/3/2022 19:09:33    Male  30-40  Pakistan              09:30
# 4    1/3/2022 19:09:34    Male  16-30      East              09:30
# ..                 ...     ...    ...       ...                ...
# 301  1/3/2022 19:11:51    Male  16-30  Pakistan              09:30
# 302  1/3/2022 19:11:52    Male  16-30  Pakistan              10:30
# 303  1/3/2022 19:11:53    Male  16-30  Pakistan              10:00
# 304  1/3/2022 19:11:54  Female  16-30  Pakistan              10:30
# 305  1/3/2022 19:11:55    Male  16-30  Pakistan              10:30
#
#      Duration (min)
# 0                60
# 1                60
# 2                30
# 3                30
# 4                60
# ..              ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

class_data = pd.read_csv("data_viz.csv")

p = sns.countplot(x = "Duration (min)", data = class_data , hue = "Age")

sns.set_theme(style = "ticks", color_codes = True)
plt.show()

# %%
import pandas as pd
import seaborn as sns

class_data["Time of class (pm)"].value_counts()
# Out:
# 10:30    125
# 10:00     99
# 09:30     82
# Name: Time of class (pm), dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([82, 99, 125])
mylabels = ["09:30 pm", "10:00 pm", "10:30 pm"]
myexplode = [0, 0, 0.2]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Section 2.1: Line Plots
# > #### Steps to follow:
# > 1. Import Libraries (Seaborn, Numpy, Matplotlib, Pandas etc.)
# > 2. Load Dataset
# > 3. Draw a Line plot
# > 4. Asthetics
# > 5. Finish

# %%
# import liibraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset

flowers = sns.load_dataset("iris")
print(flowers)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# import liibraries
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset

flowers = sns.load_dataset("iris")
# print(flowers)

# #draw a line plot

sns.lineplot(x= "sepal_length", y= "sepal_width", data= flowers)
plt.title("Data set of iris")
plt.show()

# %%
# Adding Limits

flowers = sns.load_dataset("iris")

sns.lineplot(x= "sepal_length", y= "sepal_width", data= flowers)
plt.title("Data set of iris")
plt.xlim(2)
plt.ylim(3)
plt.show()

# %%
# Set Style

from matplotlib import rc
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style="dark", rc = None)


# #load dataset

flowers = sns.load_dataset("iris")
# # print(flowers)

# #draw a line plot

sns.lineplot(x= "sepal_length", y= "sepal_width", data= flowers)
plt.title("Data set of iris")
sns.set_style("dark")
plt.show()

# %%
# Size of Figure

from matplotlib import rc
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style="dark", rc = None)


#load dataset

flowers = sns.load_dataset("iris")
# change figure size
plt.figure(figsize= (15,8))

#draw a line plot

sns.lineplot(x= "sepal_length", y= "sepal_width", data= flowers)
plt.title("Data set of iris")
sns.set_style("dark")
plt.show()

# %% [markdown]
# ## Section 2.2: Bar Plots

# %%
#import liibraries
from numpy import median
from numpy.core.fromnumeric import mean
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style= "darkgrid", rc=None)

# # #load dataset

flowers = sns.load_dataset("iris")

# change figure size
plt.figure(figsize= (8,6))

# # #draw a bar plot

sns.barplot(x= "species", y= "petal_length", data= flowers)
plt.show()

# %%
#import liibraries
from numpy import median
from numpy.core.fromnumeric import mean
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style= "darkgrid", rc=None)

boat = sns.load_dataset("titanic")
print(boat)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#import liibraries
from numpy import median
from numpy.core.fromnumeric import mean
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style(style= "darkgrid", rc=None)

boat = sns.load_dataset("titanic")

# change figure size
plt.figure(figsize= (8,6))

# # #draw a bar plot

sns.barplot(x= "class", y= "fare", hue= "sex", data= boat, estimator= mean, palette="deep", saturation= 1)
plt.show()

# %% [markdown]
# ## Section 2.3: Box Plots

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sns.set(style='whitegrid')
tip = sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# **Data Description**
# > To get the detail description of the data set

# %%
tip = sns.load_dataset("tips")
print(tip.describe())
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sns.set(style='whitegrid')
tip = sns.load_dataset("tips")

plt.figure(figsize = (10,8))

sns.boxplot(x="day", y="tip", data=tip)
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize = (10,8))
sns.boxplot(x= "tip", y="day", data= tip, hue="smoker", palette= ["C1", "C2"], dodge=True)
plt.show()

# %% [markdown]
# ## Section 2.4: Box Plots Customization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

sns.set(style='whitegrid')
tip = sns.load_dataset("tips")

sns.boxplot(x= "sex", y="tip", showmeans= True, 
meanprops = {"marker" : "D", "markersize" : "12", "markeredgecolor" : "red" }, data= tip)
plt.show()

# %% [markdown]
# ## Section 2.5: Exercise
# Line, Bar and Box Plots on Dataset collected during the class

# %% [markdown]
# ### 2.5.1: Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
class_data
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
#class_data
plt.figure(figsize = (10,6))
sns.lineplot(x = "How many hours you code a day? (int) e.g: 5,4,3" , y = "Age (years)-Float/Int" , data = class_data)
plt.title("Relationship bewtween time for coding per day and Age")
plt.show()

# %% [markdown]
# ### 2.5.2: Bar Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (10,6))
sns.barplot(x = "Qualification_completed" , y = "How many hours you code a day? (int) e.g: 5,4,3", hue = "Gender",  data = class_data, ci=None,
           order = ["Pre-Bachelors", "Bachelors", "Masters", "PhD"])
plt.title("Relationship bewtween time for coding per day and Qualification")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (10,6))
sns.barplot(x = "Location" , y = "How many hours you code a day? (int) e.g: 5,4,3", hue = "Gender",palette= ["C0", "C2"],  data = class_data, ci=None)
plt.title("Relationship bewtween time for coding per day and Location")
plt.show()

# %%
from numpy import mean
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (12,8))
sns.barplot(x = "Location" , y = "Your Weight in kg? (float)", hue = "Gender",palette= ["C7", "C2"] , data = class_data, estimator = mean)
plt.title("Relationship bewtween Weight and Location")
plt.show()

# %%
from numpy import mean
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (11,7))
sns.barplot(x = "Qualification_completed" , y = "Research/Working experience (Float/Int) years", hue = "Gender", estimator = mean, 
            color = [0.2, 0.5, 0.6, 0.4], data = class_data, order = ["Pre-Bachelors", "Bachelors", "Masters", "PhD"])
plt.title("Relationship bewtween Research Experience and Qualification")
plt.show()

# %%
from numpy import mean
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (11,7))
sns.barplot(x = "Location" , y = "Research/Working experience (Float/Int) years", hue = "Qualification_completed", estimator = mean, 
            color = [0.2,0.1,0.7,0.8], data = class_data)
plt.title("Relationship bewtween Research Experience and Location")
plt.show()

# %%
from numpy import mean
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (14,8))
sns.barplot(x = "Your favorite programming language?" , y = "Age (years)-Float/Int", estimator = mean, 
            data = class_data)
plt.title("Relationship bewtween Age and Favorite Programming Language")
plt.show()

# %% [markdown]
# ### 2.5.3: Box Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
class_data
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %%
class_data.describe()
# Out:
#        Research/Working experience (Float/Int) years  Age (years)-Float/Int  \
# count                                     375.000000             375.000000
# mean                                        2.962133              27.576933
# std                                         3.933084               7.224460
# min                                         0.000000               0.000000
# 25%                                         0.100000              24.000000
# 50%                                         2.000000              27.000000
# 75%                                         4.000000              31.000000
# max                                        40.000000              90.000000
#
#        Your Weight in kg? (float)  Height in cm? Freelancer- (Float)  \
# count                  375.000000                         375.000000
# mean                    69.321147                         162.679282
# std                     16.264434                         172.246844
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# class_data
sns.set(style='darkgrid')
plt.figure(figsize = (12,6))
sns.boxplot(x = "Qualification_completed" , y = "Research/Working experience (Float/Int) years", showmeans= True, 
meanprops = {"marker" : "*", "markersize" : "12", "markeredgecolor" : "red" },data=class_data)
plt.title("Relationship between Research/Working Experience and Qualification of the participants")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# class_data
sns.set(style='darkgrid')
plt.figure(figsize = (12,6))
sns.boxplot(x = "Your favorite programming language?" , y = "How many hours you code a day? (int) e.g: 5,4,3", data=class_data)
plt.title("Relationship bewtween Hours of coding per day and Favorite Programming Language")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# class_data
sns.set(style='darkgrid')
plt.figure(figsize = (12,6))
sns.boxplot(x = "Location" , y = "Your Weight in kg? (float)", hue = "Gender",showmeans= True, 
meanprops = {"marker" : "*", "markersize" : "12", "markeredgecolor" : "green" } , data=class_data)
plt.title("Relationship bewtween Weight and Location")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
class_data = pd.read_csv("Chilla_data2_for_plots.csv")
# print(class_data)
sns.set(style='darkgrid')
plt.figure(figsize = (12,6))
sns.boxplot(x = "Location" , y = "Research/Working experience (Float/Int) years", hue = "Qualification_completed", 
            data = class_data)
plt.title("Relationship bewtween Research Experience and Location")
plt.show()

# %% [markdown]
# ## Section 2.6: Plotly

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px

df = px.data.gapminder().query("year == 2007")
fig = px.sunburst(df, path=['continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'])
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
df = px.data.tips()
fig = px.violin(df, y="tip", x="smoker", color="sex", box=True, points="all", hover_data=df.columns)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
df = px.data.tips()
fig = px.strip(df, x="total_bill", y="time", orientation="h", color="smoker")
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
data=[[1, 25, 30, 50, 1], [20, 1, 60, 80, 30], [30, 60, 1, 5, 20]]
fig = px.imshow(data,
                labels=dict(x="Day of Week", y="Time of Day", color="Productivity"),
                x=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'],
                y=['Morning', 'Afternoon', 'Evening']
               )
fig.update_xaxes(side="top")
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
df = px.data.carshare()
fig = px.scatter_mapbox(df, lat="centroid_lat", lon="centroid_lon", color="peak_hour", size="car_hours",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10,
                  mapbox_style="carto-positron")
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px

df = px.data.election()
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(df, geojson=geojson, color="Bergeron",
                           locations="district", featureidkey="properties.district",
                           center={"lat": 45.5517, "lon": -73.7073},
                           mapbox_style="carto-positron", zoom=9)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.gapminder()
fig = px.choropleth(df, locations="iso_alpha", color="lifeExp", hover_name="country", animation_frame="year", range_color=[20,80])
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.wind()
fig = px.scatter_polar(df, r="frequency", theta="direction", color="strength", symbol="strength",
            color_discrete_sequence=px.colors.sequential.Plasma_r)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.wind()
fig = px.bar_polar(df, r="frequency", theta="direction", color="strength", template="plotly_dark",
            color_discrete_sequence= px.colors.sequential.Plasma_r)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
import numpy as np
df = px.data.gapminder().query("year == 2007")
fig = px.treemap(df, path=[px.Constant('world'), 'continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'])
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country", facet_col="continent",
           log_x=True, size_max=45, range_x=[100,100000], range_y=[25,90])
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.gapminder()
fig = px.scatter(df.query("year==2007"), x="gdpPercap", y="lifeExp", size="pop", color="continent",
           hover_name="country", log_x=True, size_max=60)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"
import plotly.express as px
df = px.data.iris()
fig = px.parallel_coordinates(df, color="species_id", labels={"species_id": "Species",
                  "sepal_width": "Sepal Width", "sepal_length": "Sepal Length",
                  "petal_width": "Petal Width", "petal_length": "Petal Length", },
                    color_continuous_scale=px.colors.diverging.Tealrose, color_continuous_midpoint=2)
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
df = px.data.iris()
fig = px.scatter_matrix(df, dimensions=["sepal_width", "sepal_length", "petal_width", "petal_length"], color="species")
fig.show()

# %%
import plotly.io as pio
pio.renderers.default = "png"

import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
fig.show()
